# %%
import pandas as pd

# %%
df = pd.read_csv('/vol/v1/proj/LTOP_FTV_Py/selected_lt_params/testing_intermediate_200_cluster_output_revised_columns_exclusion.csv')
df.head()
subset = df.loc[df.cluster_id == 37]
subset['index'].unique()

subset = subset.loc[df['index'] == 'TCW']
# subset.columns
subset.shape
# subset.selected
selected_rows = subset.loc[df.selected == 101]
selected_rows

# tcw_vals = pd.read_csv('/vol/v1/proj/LTOP_FTV_Py/output_04_Cambodia_200/LTOP_Cambodia_200_abstractImageSample_lt_144params_TCW_c2_selected.csv')
# tcw_vals = tcw_vals.loc[tcw_vals.cluster_id == 37]
# tcw_vals.shape
# tcw_vals.columns
# tcw_vals.loc[tcw_vals.param_num == 72]['params']
# # selected_rows.recoveryThreshold
# param_numbers = selected_rows.params
# # param_numbers.iloc[0]
# param_numbers
# Out:
#        cluster_id                                             fitted index  \
# 27216          37  [-1387.5969128188474, -1386.098998827755, -138...   TCW
# 27217          37  [-1387.5969128188474, -1386.098998827755, -138...   TCW
# 27218          37  [-1387.5969128188474, -1386.098998827755, -138...   TCW
# 27219          37  [-1387.5969128188474, -1386.098998827755, -138...   TCW
# 27220          37  [-1387.5969128188474, -1386.098998827755, -138...   TCW
# 27221          37  [-1387.5969128188474, -1386.098998827755, -138...   TCW
# 27222          37  [-1387.5969128188474, -1386.098998827755, -138...   TCW
# 27223          37  [-1387.5969128188474, -1386.098998827755, -138...   TCW
# 27224          37  [-1387.5969128188474, -1386.098998827755, -138...   TCW
# 27225          37  [-1387.5969128188474, -1386.098998827755, -138...   TCW
# 27226          37  [-1387.5969128188474, -1386.098998827755, -138...   TCW
# ...
